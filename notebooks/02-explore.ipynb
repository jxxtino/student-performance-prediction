# %%
import pandas as pd

# %%
train = pd.read_csv("../data/02-interim/train.csv")
test = pd.read_csv("../data/02-interim/test.csv")

# %%
train.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0    male        group E                some college      standard
# 1  female        group A           bachelor's degree      standard
# 2    male        group C           bachelor's degree      standard
# 3  female        group E          associate's degree      standard
# 4  female        group E                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score  target
# 0                    none          68             72             65   68.33
# 1                    none          59             72             70   67.00
# 2               completed          94             90             91   91.67
# 3               completed          65             75             77   72.33
# 4               completed          75             88             85   82.67

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       194 non-null    object
#  1   race/ethnicity               194 non-null    object
#  2   parental level of education  194 non-null    object
#  3   lunch                        194 non-null    object
#  4   test preparation course      194 non-null    object
#  5   math score                   194 non-null    int64
#  6   reading score                194 non-null    int64
#  7   writing score                194 non-null    int64
#  8   target                       194 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 13.8+ KB

# %%
train.describe()
# Out:
#        math score  reading score  writing score     target
# count  775.000000     775.000000     775.000000  775.00000
# mean    66.623226      69.556129      68.461935   68.21369
# std     14.383273      13.807616      14.431010   13.43129
# min     18.000000      26.000000      22.000000   26.00000
# 25%     57.000000      60.000000      58.000000   58.67000
# 50%     67.000000      70.000000      69.000000   68.67000
# 75%     77.000000      79.000000      78.500000   77.67000
# max    100.000000     100.000000     100.000000  100.00000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(train["target"], kde=True)
plt.title("Average Score Distribution")
# Out:
# Text(0.5, 1.0, 'Average Score Distribution')

# %%
num_cols = ["math score", "reading score", "writing score"]

sns.pairplot(
    train[num_cols + ["target"]],
    diag_kind="kde"
)

plt.savefig("../report/figures/pairplot.png", dpi=120, bbox_inches="tight")

# %%
corr = train[num_cols + ["target"]].corr(method="pearson")

sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.boxplot(
    data=train,
    x="gender",
    y="target"
)
# Out:
# <Axes: xlabel='gender', ylabel='target'>

# %%
sns.boxplot(
    data=train,
    x="parental level of education",
    y="target"
)
# Out:
# <Axes: xlabel='parental level of education', ylabel='target'>

# %%
sns.boxplot(
    data=train,
    x="lunch",
    y="target"    
)
# Out:
# <Axes: xlabel='lunch', ylabel='target'>

# %%
sns.boxplot(
    data=train,
    x="test preparation course",
    y="target"    
)
# Out:
# <Axes: xlabel='test preparation course', ylabel='target'>
